# %% [markdown]
# # Maximizing AI Potentials: Leveraging Foundational Models from Amazon Bedrock and Amazon OpenSearch Serverless as Vector Engine
#
# ### Context
# Amazon Bedrock is a fully managed service that provides access to FMs from third-party providers and Amazon; available via an API. With Bedrock, you can choose from a variety of models to find the one that’s best suited for your use case. On one hand Amazon Bedrock provides an option to generate vectors as well as summarizezation of texts, then on other hands vector engine for Amazon OpenSearch Serverless complements it by providing a machinsm to store those vectors and run semantic search against those vectors.
#
# In this sample notebook you will explore some of the most common usage patterns we are seeing with our customers for Generative AI such as generating text and images, creating value for organizations by improving productivity. This is achieved by leveraging foundation models to help in composing emails, summarizing text, answering questions, building chatbots, and creating images.
#
# ### Challenges
# - How to manage large document(s) that exceed the token limit
# - How to find the document(s) relevant to the question being asked
#
# ### Proposal
# To the above challenges, this notebook proposes the following strategy
# #### Prepare documents
# ![Embeddings](./images/Embeddings_lang.png)
#
# Before being able to answer the questions, the documents must be processed and a stored in a document store index
# - Load the documents
# - Process and split them into smaller chunks
# - Create a numerical vector representation of each chunk using Amazon Bedrock Titan Embeddings model
# - Create an index using the chunks and the corresponding embeddings and store into OpenSearch Serverless
# #### Ask question
# ![Question](./images/Chatbot_lang.png)
#
# When the documents index is prepared, you are ready to ask the questions and relevant documents will be fetched based on the question being asked. Following steps will be executed.
# - Create an embedding of the input question
# - Compare the question embedding with the embeddings stored in OpenSearch Serverless
# - Fetch the (top N) relevant document chunks using vector engine
# - Add those chunks as part of the context in the prompt
# - Send the prompt to the model under Amazon Bedrock
# - Get the contextual answer based on the documents retrieved

# %% [markdown]
# ## Usecase
# #### Dataset
# To explain this architecture pattern we are using the documents from IRS. These documents explain topics such as:
# - Original Issue Discount (OID) Instruments
# - Reporting Cash Payments of Over $10,000 to IRS
# - Employer's Tax Guide
#
# The model will try to answer from the documents in easy language.

# %% [markdown]
# ## Implementation
# In order to follow the RAG approach this notebook is using the LangChain framework where it has integrations with different services and tools that allow efficient building of patterns such as RAG. We will be using the following tools:
#
# - **LLM (Large Language Model)**: Anthropic Claude V1 available through Amazon Bedrock
# - **Vector Store**: vector engine for Amazon OpenSearch Serverless
#   In this notebook we are using OpenSearch Serverless as a vector-store to store both the embeddings and the documents.
# - **Index**: VectorIndex - This model will be used to understand the document chunks and provide an answer in human friendly manner.
# - **Embeddings Model**: Amazon Titan Embeddings available through Amazon Bedrock
#
#   This model will be used to generate a numerical representation of the textual documents
# - **Document Loader**: PDF Loader available through LangChain
#
#   This is the loader that can load the documents from a source, in this example we are loading the vector embeddings generated from those file chunks to OpenSearch Serverless.
#
#   The index helps to compare the input embedding and the document embeddings to find relevant document
# - **Wrapper**: wraps index, vector store, embeddings model and the LLM to abstract away the logic from the user.
#
# ### Setup
# To run this notebook you would need to install dependencies such as, [PyPDF](https://pypi.org/project/pypdf/)
#
#
#
# Then begin with instantiating the LLM and the Embeddings model. Here we are using Amazon Titan to demonstrate the use case.
#
# Note: It is possible to choose other models available with Bedrock. You can replace the `model_id` as follows to change the model.
#
# `llm = Bedrock(model_id="amazon.titan-tg1-large")`
#
# Available models under Bedrock have the following IDs:
# - `amazon.titan-tg1-large`
# - `ai21.j2-grande-instruct`
# - `ai21.j2-jumbo-instruct`
# - `anthropic.claude-instant-v1`
# - `anthropic.claude-v1`

# %% [markdown]
# #### ⚠️⚠️⚠️ Execute the following cells before running this notebook ⚠️⚠️⚠️
#
# For a detailed description on what the following cells do refer to [Bedrock boto3 setup](../00_Intro/bedrock_boto3_setup.ipynb) notebook.

# %%
# Make sure you run `download-dependencies.sh` from the root of the repository to download the dependencies before running this cell
# %pip install ./dependencies/botocore-1.29.162-py3-none-any.whl ./dependencies/boto3-1.26.162-py3-none-any.whl ./dependencies/awscli-1.27.162-py3-none-any.whl --force-reinstall
# %pip install langchain==0.0.245 --quiet
# %pip install pypdf==3.8.1 faiss-cpu==1.7.4 --quiet
# %pip install requests_aws4auth opensearch-py
# Out:
# WARNING: Requirement './dependencies/botocore-1.29.162-py3-none-any.whl' looks like a filename, but the file does not exist
# WARNING: Requirement './dependencies/boto3-1.26.162-py3-none-any.whl' looks like a filename, but the file does not exist
# WARNING: Requirement './dependencies/awscli-1.27.162-py3-none-any.whl' looks like a filename, but the file does not exist
# Processing ./dependencies/botocore-1.29.162-py3-none-any.whl
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/Users/mankhanu/Github/test/amazon-bedrock-workshop/03_QuestionAnswering/dependencies/botocore-1.29.162-py3-none-any.whl'
#
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests_aws4auth in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (1.2.3)
# Requirement already satisfied: opensearch-py in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: requests in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (from requests_aws4auth) (2.31.0)
# Requirement already satisfied: six in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (from requests_aws4auth) (1.16.0)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (from opensearch-py) (1.26.16)
# Requirement already satisfied: python-dateutil in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (from opensearch-py) (2.8.2)
# Requirement already satisfied: certifi>=2022.12.07 in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (from opensearch-py) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (from requests->requests_aws4auth) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mankhanu/miniconda/envs/bedrock-30/lib/python3.10/site-packages (from requests->requests_aws4auth) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
#### Un comment the following lines to run from your local environment outside of the AWS account with Bedrock access

# import os
# os.environ['BEDROCK_ASSUME_ROLE'] = '<enter role>'
# os.environ['AWS_PROFILE'] = '<aws-profile>'

# %%
import boto3
import json
import os
import sys

module_path = ".."
sys.path.append(os.path.abspath(module_path))
from utils import bedrock, print_ww

os.environ['AWS_DEFAULT_REGION'] = 'us-east-1'
boto3_bedrock = bedrock.get_bedrock_client(os.environ.get('BEDROCK_ASSUME_ROLE', None))
print (f"bedrock client {boto3_bedrock}")
# Out:
# Create new client
#   Using region: us-east-1
# boto3 Bedrock client successfully created!
# bedrock(https://bedrock.us-east-1.amazonaws.com)
# bedrock client <botocore.client.Bedrock object at 0x7fb140475060>

# %%
## set up opensearch
from opensearchpy import OpenSearch, RequestsHttpConnection
from requests_aws4auth import AWS4Auth
import json

# create open search collection public endpoint from public preview in us-east-2
host = 'jobm91bhqffl30fsl22a.us-east-2.aoss.amazonaws.com' # OpenSearch Serverless collection endpoint
region = 'us-east-2' # e.g. us-west-2

service = 'aoss'
credentials = boto3.Session().get_credentials()
awsauth = AWS4Auth(credentials.access_key, credentials.secret_key, region, service,
session_token=credentials.token)

# Create an OpenSearch client
client = OpenSearch(
    hosts = [{'host': host, 'port': 443}],
    http_auth = awsauth,
    timeout = 300,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection
)

# %% [markdown]
# ### Setup langchain
#
# We create an instance of the Bedrock classes for the LLM and the embedding models. In this example we are showing an example with "titan" model from Amazon, and "claude" model from Anthropic.

# %%
# We will be using the Titan Embeddings Model to generate our Embeddings.
from langchain.embeddings import BedrockEmbeddings
from langchain.llms.bedrock import Bedrock

# - create the Anthropic Model
claude_llm = Bedrock(model_id="anthropic.claude-v1", client=boto3_bedrock, model_kwargs={'max_tokens_to_sample':200})
titan_llm = Bedrock(model_id= "amazon.titan-tg1-large", client=boto3_bedrock)
bedrock_embeddings = BedrockEmbeddings(client=boto3_bedrock)

# %% [markdown]
# ### Data Preparation
# Let's first download some of the files to build our document store. For this example we will be using public IRS documents from [here](https://www.irs.gov/publications).

# %%
# !mkdir data

from urllib.request import urlretrieve
files = [
    'https://www.irs.gov/pub/irs-pdf/p1544.pdf',
    'https://www.irs.gov/pub/irs-pdf/p15.pdf',
    'https://www.irs.gov/pub/irs-pdf/p1212.pdf'
]
for url in files:
    file_path = './data/' + url.split('/')[-1]
    urlretrieve(url, file_path)
# Out:
# mkdir: data: File exists

# %% [markdown]
# After downloading we can load the documents with the help of [DirectoryLoader from PyPDF available under LangChain](https://python.langchain.com/en/latest/reference/modules/document_loaders.html) and splitting them into smaller chunks.
#
# Note: The retrieved document/text should be large enough to contain enough information to answer a question; but small enough to fit into the LLM prompt. Also the embeddings model has a limit of the length of input tokens limited to 512 tokens, which roughly translates to ~2000 characters. For the sake of this use-case we are creating chunks of roughly 1000 characters with an overlap of 100 characters using [RecursiveCharacterTextSplitter](https://python.langchain.com/en/latest/modules/indexes/text_splitters/examples/recursive_text_splitter.html).

# %%
import numpy as np
from langchain.text_splitter import CharacterTextSplitter, RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader, PyPDFDirectoryLoader

loader = PyPDFDirectoryLoader("./data/")

documents = loader.load()
# - in our testing Character split works better with this PDF data set
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size = 1000,
    chunk_overlap  = 100,
)
docs = text_splitter.split_documents(documents)

# %%
avg_doc_length = lambda documents: sum([len(doc.page_content) for doc in documents])//len(documents)
avg_char_count_pre = avg_doc_length(documents)
avg_char_count_post = avg_doc_length(docs)
print(f'Average length among {len(documents)} documents loaded is {avg_char_count_pre} characters.')
print(f'After the split we have {len(docs)} documents more than the original {len(documents)}.')
print(f'Average length among {len(docs)} documents (after split) is {avg_char_count_post} characters.')
# Out:
# Average length among 73 documents loaded is 5850 characters.
# After the split we have 503 documents more than the original 73.
# Average length among 503 documents (after split) is 910 characters.

# %% [markdown]
# We had 3 PDF documents which have been split into smaller ~500 chunks.
#
# Now we can see how a sample embedding would look like for one of those chunks

# %%
query_embedding = np.array(bedrock_embeddings.embed_query(docs[0].page_content))
np.array(query_embedding)
# Out:
# array([-0.15917969,  0.76171875,  0.24511719, ...,  0.12109375,
#        -0.25585938,  0.06591797])

# %% [markdown]
#
# The below function will establish a connection with OpenSearch Serverless, create a new index, create embeddings for the documents and then store the embeddings in OpenSearch serverless. For details on documentation refer this link: https://python.langchain.com/docs/integrations/vectorstores/opensearch
#
# *Note: Wait for a minute or two after the below command to excute, before the new index can be queried.*

# %%
# TODO - Direct langchain integration with version 0.0.245 gives timeout error, therefore, commenting the following code. 

# from langchain.vectorstores import OpenSearchVectorSearch

# docsearch = OpenSearchVectorSearch.from_documents(
#     docs,
#     bedrock_embeddings,
#     opensearch_url=host,
#     http_auth=awsauth,
#     timeout = 300,
#     use_ssl = True,
#     verify_certs = True,
#     connection_class = RequestsHttpConnection,
#     index_name="bedrock-aos-irs-index2",
#     engine="faiss",
#     bulk_size=len(docs)
# )

# %%
index_name = "bedrock-aos-demo-new1"
vector_size = 4096

# %%
# create a new index
index_body = {
    "settings": {
        "index.knn": True
  },
  'mappings': {
    'properties': {
      "title": { "type": "text", "fields": { "keyword": { "type": "keyword" } } }, #the field will be title.keyword and the data type will be keyword, this will act as sub field for
      "v_title": { "type": "knn_vector", "dimension": vector_size },
    }
  }
}

client.indices.create(
  index=index_name, 
  body=index_body
)
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'index': 'bedrock-aos-demo-new1'}

# %%
# python code to view schema for OpenSearch Serverless. 
client.indices.get_mapping(index_name)
# Out:
# {'bedrock-aos-demo-new1': {'mappings': {'properties': {'title': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword'}}},
#     'v_title': {'type': 'knn_vector', 'dimension': 4096}}}}}

# %%
actions =[]
bulk_size = 0
action = {"index": {"_index": index_name}}


# # Prepare bulk request
# actions.append(action)
# actions.append(json_data.copy())

# %%
# Bulk API to ingest documents in OSS.
# it will take about 5 mins to ingest the 503 vectors
for document in docs: 
    sample_embedding = np.array(bedrock_embeddings.embed_query(document.page_content))
    actions.append(action)
    json_data = {
             "title" : document.page_content,
            "v_title" : sample_embedding
        }
    actions.append(json_data)
    bulk_size+=1
    if(bulk_size > 200 ):
        client.bulk(body=actions)
        print(f"bulk request sent with size: {bulk_size}")
        bulk_size = 0

#ingest remaining documents
print("remaining documents: ", bulk_size)
client.bulk(body=actions)
# Out:
# bulk request sent with size: 201
# bulk request sent with size: 201
# remaining documents:  101
# {'took': 1008,
#  'errors': False,
#  'items': [{'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AYF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AYV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AYl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AY19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AZF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AZV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AZl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AZ19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AaF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AaV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aal9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aa19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AbF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AbV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Abl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ab19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AcF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AcV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Acl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ac19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AdF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AdV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Adl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ad19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AeF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AeV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ael9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ae19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AfF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AfV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Afl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Af19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AgF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AgV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Agl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ag19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AhF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AhV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ahl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ah19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AiF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AiV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ail9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ai19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AjF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AjV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ajl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aj19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AkF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AkV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Akl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ak19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AlF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AlV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3All9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Al19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AmF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AmV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aml9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Am19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AnF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AnV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Anl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3An19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AoF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AoV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aol9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ao19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ApF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ApV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Apl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ap19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AqF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AqV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aql9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aq19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ArF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ArV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Arl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ar19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AsF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AsV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Asl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3As19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AtF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AtV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Atl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3At19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AuF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AuV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aul9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Au19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AvF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AvV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Avl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Av19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AwF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AwV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Awl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Aw19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AxF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AxV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Axl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ax19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AyF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AyV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ayl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ay19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AzF9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AzV9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Azl9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Az19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A0F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A0V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A0l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A019Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A1F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A1V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A1l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A119Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A2F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A2V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A2l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A219Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A3F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A3V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A3l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A319Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A4F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A4V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A4l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A419Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A5F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A5V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A5l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A519Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A6F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A6V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A6l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A619Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A7F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A7V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A7l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A719Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A8F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A8V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A8l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A819Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A9F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A9V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A9l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A919Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A-F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A-V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A-l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A-19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A_F9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A_V9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A_l9Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3A_19Ws4kBYEx0HOrvedTs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AAF9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AAV9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AAl9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AA19Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ABF9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ABV9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ABl9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AB19Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ACF9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ACV9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ACl9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AC19Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ADF9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ADV9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ADl9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AD19Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AEF9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AEV9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AEl9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AE19Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AFF9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AFV9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AFl9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AF19Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AGF9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AGV9Ws4kBYEx0HOrvedXs',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
# ...
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AGV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AGl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AG19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AHF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AHV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AHl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AH19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AIF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AIV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AIl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AI19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AJF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AJV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AJl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AJ19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AKF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AKV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AKl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AK19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ALF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ALV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ALl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AL19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AMF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AMV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AMl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AM19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ANF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ANV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ANl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AN19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AOF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AOV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AOl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AO19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3APF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3APV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3APl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AP19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AQF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AQV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AQl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AQ19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ARF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ARV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ARl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AR19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ASF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ASV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ASl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AS19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ATF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ATV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ATl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AT19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AUF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AUV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AUl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AU19Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AVF9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AVV9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}},
#   {'index': {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AVl9Ws4kBYEx0HOrvedbu',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 0, 'successful': 0, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 0,
#     'status': 201}}]}

# %% [markdown]
# Following the similar pattern embeddings could be generated for the entire corpus and stored in a vector store.
# **⚠️⚠️⚠️ NOTE: it might take few minutes to run the following cell ⚠️⚠️⚠️**

# %% [markdown]
# ### Question Answering
#
# Now that we have our vector store in place, we can start asking questions.

# %%
query = "Is it possible that I get sentenced to jail due to failure in filings?"

# %% [markdown]
# The first step would be to create an embedding of the query such that it could be compared with the documents

# %%
query_embedding = np.array(bedrock_embeddings.embed_query(query))
np.array(query_embedding)
# Out:
# array([-0.11181641, -0.20019531,  0.00915527, ..., -0.4921875 ,
#        -0.05664062,  0.43359375])

# %%
index_name
# Out:
# 'bedrock-aos-demo-new1'

# %%
query_os = {
  "size": 3,
  "fields": ["title"],
  "_source": False,
  "query": {
    "knn": {
      "v_title": {
        "vector": query_embedding,
        "k": vector_size
      }
    }
  }
}

relevant_documents = client.search(
body = query_os,
index = index_name
)

# %%
relevant_documents
# Out:
# {'took': 86,
#  'timed_out': False,
#  '_shards': {'total': 0, 'successful': 0, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 603, 'relation': 'eq'},
#   'max_score': 0.0019617553,
#   'hits': [{'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3Ar19Vs4kBYEx0HOrvINPF',
#     '_score': 0.0019617553,
#     'fields': {'title': ['There are civil penalties for failure to:\nFile a correct Form 8300 by the date it is \ndue, and\nProvide the required statement to those \nnamed in the Form 8300.\nIf you intentionally disregard the requirement \nto file a correct Form 8300 by the date it is due, \nthe penalty is the greater of:\n1.$25,000, or\n2.The amount of cash you received and \nwere required to report (up to $100,000).\nThere are criminal penalties for:\nWillful failure to file Form 8300,\nWillfully filing a false or fraudulent Form \n8300,\nStopping or trying to stop Form 8300 from \nbeing filed, and\nSetting up, helping to set up, or trying to \nset up a transaction in a way that would \nmake it seem unnecessary to file Form \n8300.\nIf you willfully fail to file Form 8300, you can \nbe fined up to $250,000 for individuals \nRECORDS($500,000 for corporations) or sentenced to up \nto 5 years in prison, or both. These dollar \namounts are based on Section 3571 of Title 18 \nof the U.S. Code.']}},
#    {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3ARZFVs4kB7HGcmLnF9FGI',
#     '_score': 0.0019617553,
#     'fields': {'title': ['There are civil penalties for failure to:\nFile a correct Form 8300 by the date it is \ndue, and\nProvide the required statement to those \nnamed in the Form 8300.\nIf you intentionally disregard the requirement \nto file a correct Form 8300 by the date it is due, \nthe penalty is the greater of:\n1.$25,000, or\n2.The amount of cash you received and \nwere required to report (up to $100,000).\nThere are criminal penalties for:\nWillful failure to file Form 8300,\nWillfully filing a false or fraudulent Form \n8300,\nStopping or trying to stop Form 8300 from \nbeing filed, and\nSetting up, helping to set up, or trying to \nset up a transaction in a way that would \nmake it seem unnecessary to file Form \n8300.\nIf you willfully fail to file Form 8300, you can \nbe fined up to $250,000 for individuals \nRECORDS($500,000 for corporations) or sentenced to up \nto 5 years in prison, or both. These dollar \namounts are based on Section 3571 of Title 18 \nof the U.S. Code.']}},
#    {'_index': 'bedrock-aos-demo-new1',
#     '_id': '1%3A0%3AIpFVs4kB7HGcmLnF9FKJ',
#     '_score': 0.001732385,
#     'fields': {'title': ['Page 31 of 49  Fileid: … ations/p15/2023/a/xml/cycle05/source 15:08 - 13-Dec-2022\nThe type and rule above prints on all proofs including departmental reproduction proofs. MUST be removed before printing.\nPenalty Charged for...\n2% Deposits made 1 to 5 days late.\n5% Deposits made 6 to 15 days late.\n10% Deposits made 16 or more days late, but before 10 days from \nthe date of the first notice the IRS sent asking for the tax due.\n10% Amounts that should have been deposited, but instead were \npaid directly to the IRS, or paid with your tax return. But see \nPayment with return , earlier in this section, for exceptions.\n15% Amounts still unpaid more than 10 days after the date of the \nfirst notice the IRS sent asking for the tax due or the day on \nwhich you received notice and demand for immediate \npayment, whichever is earlier.\nLate deposit penalty amounts are determined using \ncalendar days, starting from the due date of the liability.\nSpecial rule for former Form 944 filers.  If you filed']}}]}}

# %% [markdown]
# We can use this embedding of the query to then fetch relevant documents.
# Now our query is represented as embeddings we can do a similarity search of our query against our data store providing us with the most relevant information.

# %%
print(len(relevant_documents["hits"]["hits"]))
print("--------------------")
context = " "
for i, rel_doc in enumerate(relevant_documents["hits"]["hits"]):
    print_ww(f'## Document {i+1}: {relevant_documents["hits"]["hits"][i]["fields"]["title"][0]}.......')
    print('---')
    context += relevant_documents["hits"]["hits"][i]["fields"]["title"][0]
# Out:
# 3
# --------------------
# ## Document 1: There are civil penalties for failure to:
# File a correct Form 8300 by the date it is
# due, and
# Provide the required statement to those
# named in the Form 8300.
# If you intentionally disregard the requirement
# to file a correct Form 8300 by the date it is due,
# the penalty is the greater of:
# 1.$25,000, or
# 2.The amount of cash you received and
# were required to report (up to $100,000).
# There are criminal penalties for:
# Willful failure to file Form 8300,
# Willfully filing a false or fraudulent Form
# 8300,
# Stopping or trying to stop Form 8300 from
# being filed, and
# Setting up, helping to set up, or trying to
# set up a transaction in a way that would
# make it seem unnecessary to file Form
# 8300.
# If you willfully fail to file Form 8300, you can
# be fined up to $250,000 for individuals
# RECORDS($500,000 for corporations) or sentenced to up
# to 5 years in prison, or both. These dollar
# amounts are based on Section 3571 of Title 18
# of the U.S. Code........
# ---
# ## Document 2: There are civil penalties for failure to:
# File a correct Form 8300 by the date it is
# due, and
# Provide the required statement to those
# named in the Form 8300.
# If you intentionally disregard the requirement
# to file a correct Form 8300 by the date it is due,
# the penalty is the greater of:
# 1.$25,000, or
# 2.The amount of cash you received and
# were required to report (up to $100,000).
# There are criminal penalties for:
# Willful failure to file Form 8300,
# Willfully filing a false or fraudulent Form
# 8300,
# Stopping or trying to stop Form 8300 from
# being filed, and
# Setting up, helping to set up, or trying to
# set up a transaction in a way that would
# make it seem unnecessary to file Form
# 8300.
# If you willfully fail to file Form 8300, you can
# be fined up to $250,000 for individuals
# RECORDS($500,000 for corporations) or sentenced to up
# to 5 years in prison, or both. These dollar
# amounts are based on Section 3571 of Title 18
# of the U.S. Code........
# ---
# ## Document 3: Page 31 of 49  Fileid: … ations/p15/2023/a/xml/cycle05/source 15:08 - 13-Dec-2022
# The type and rule above prints on all proofs including departmental reproduction proofs. MUST be
# removed before printing.
# Penalty Charged for...
# 2% Deposits made 1 to 5 days late.
# 5% Deposits made 6 to 15 days late.
# 10% Deposits made 16 or more days late, but before 10 days from
# the date of the first notice the IRS sent asking for the tax due.
# 10% Amounts that should have been deposited, but instead were
# paid directly to the IRS, or paid with your tax return. But see
# Payment with return , earlier in this section, for exceptions.
# 15% Amounts still unpaid more than 10 days after the date of the
# first notice the IRS sent asking for the tax due or the day on
# which you received notice and demand for immediate
# payment, whichever is earlier.
# Late deposit penalty amounts are determined using
# calendar days, starting from the due date of the liability.
# Special rule for former Form 944 filers.  If you filed.......
# ---

# %%
parameters = {
    "maxTokenCount":512,
    "stopSequences":[],
    "temperature":0,
    "topP":0.9
    }

# %%
query
# Out:
# 'Is it possible that I get sentenced to jail due to failure in filings?'

# %%
prompt_data_claude = f"""Human: Answer the question based only on the information provided. If the answer is not in the context, say "I don't know, answer not found in the documents. Provide quote from the document.
<context>
{context}
</context>
<question>
{query}
</question>
Assistant:"""

# %%
output_text_claude = claude_llm(prompt_data_claude)

print ("########## Ouput from Claude Model #################\n")
print(output_text_claude)
# Out:
# ########## Ouput from Claude Model #################
#
#  Yes, it is possible to be sentenced to jail for failure to file Form 8300. The document states:
#
# "There are criminal penalties for:
# Willful failure to file Form 8300,
# Willfully filing a false or fraudulent Form
# 8300,
# Stopping or trying to stop Form 8300 from
# being filed, and
# Setting up, helping to set up, or trying to
# set up a transaction in a way that would
# make it seem unnecessary to file Form
# 8300.
# If you willfully fail to file Form 8300, you can
# be fined up to $250,000 for individuals
# RECORDS($500,000 for corporations) or sentenced to up
# to 5 years in prison, or both."

# %%
prompt_data_titan = f"""Answer the below question based on the context provided. If the answer is not in the context, say "I don't know, answer not found in the documents".
{context}
{query}
"""

# %%
output_text_titan = titan_llm(prompt_data_titan)
print ("########## Ouput from Titan Model ################\n")
print(output_text_titan)
# Out:
# ########## Ouput from Titan Model ################
#
# Sorry, this model is designed to avoid giving legal advice. Please see our content limitations page for more information.
#
# Based on the provided context:
# The penalty for willful failure to file Form 8300 is a fine of up to $250,000 for individuals or $500,000 for corporations, or up to 5 years in prison, or both.

# %% [markdown]
# ## Conclusion
# Congratulations on completing this moduel on retrieval augmented generation! This is an important technique that combines the power of large language models with the precision of retrieval methods. By augmenting generation with relevant retrieved examples, the responses we recieved become more coherent, consistent and grounded. You should feel proud of learning this innovative approach. I'm sure the knowledge you've gained will be very useful for building creative and engaging language generation systems. Well done!
#
# In the above implementation of RAG based Question Answering we have explored the following concepts and how to implement them using Amazon Bedrock and it's LangChain integration.
#
# - Loading documents and generating embeddings to create a vector store
# - Retrieving documents to the question
# - Preparing a prompt which goes as input to the LLM
# - Present an answer in a human friendly manner
#
# ### Take-aways
# - Experiment with different Vector Stores
# - Leverage various models available under Amazon Bedrock to see alternate outputs
# - Explore options such as persistent storage of embeddings and document chunks
# - Integration with enterprise data stores
#
# # Thank You
